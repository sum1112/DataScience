# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = load_boston().data

# %%
features = load_boston().feature_names

# %%
data = pd.DataFrame(data=data, columns=features)

# %%
data['PRICE'] = load_boston().target

# %%
plt.figure(figsize=(16, 10))
sns.set()
sns.heatmap(data.corr(), mask=mask, annot=True, square=True)
plt.show()

# %%
mask = np.full((14, 14), 0)
mask[np.triu_indices_from(mask)] = True

# %%
plt.figure(figsize=(12,9))
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set()
sns.regplot(x=data['TAX'], y=data['RAD'])
sns.jointplot(y=data['TAX'], x=data['RAD'], size=7, color='indigo', joint_kws={'alpha': 0.5})
print(data['TAX'].corr(data['RAD']))
plt.show()
# Out:
# 0.9102281885331845

# %%
plt.figure(figsize=(15,10))
sns.set_context('talk')
sns.set_style('whitegrid')
sns.set()
sns.lmplot(x='RM', y='PRICE', data=data, size=7)
print(data['RM'].corr(data['PRICE']))
plt.show()
# Out:
# 0.695359947071539
# C:\Users\sumit\Anaconda4\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# %%time 

sns.pairplot(data)
plt.show()
# Out:
# Wall time: 33.2 s

# %%
data['PRICE'].corr(data['INDUS'])
# Out:
# -0.48372516002837285

# %%
prices = data['PRICE']
features = data.drop('PRICE', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.2)

print(regr.score(X_test, y_test))
print(regr.score(X_train, y_train))
# Out:
# 0.7155484978630369
# 0.7434409726639732

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)

print('Intercept', regr.intercept_)
pd.DataFrame(data=regr.coef_, index=X_train.columns)
# Out:
# Intercept 38.8357181271888
#                  0
# CRIM     -0.118414
# ZN        0.063433
# INDUS    -0.024518
# CHAS      3.198583
# NOX     -15.024779
# RM        3.150326
# AGE      -0.001165
# DIS      -1.597146
# RAD       0.315347
# TAX      -0.013171
# PTRATIO  -0.846159
# B         0.008810
# LSTAT    -0.558378

# %%
x = np.array([[1, 2, 3], [4, 5, 6]])
d = pd.DataFrame(data=x, columns=['A', 'B', 'C'])
d
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
